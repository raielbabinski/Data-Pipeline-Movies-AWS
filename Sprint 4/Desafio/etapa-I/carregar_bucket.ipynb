# %%
import boto3

# %% [markdown]
# Faz a configurção do session, passa qual conta AWS vai ser usada, e as chaves de acesso (AWS CLI).

# %%
session = boto3.Session(
    profile_name='559050252078_AdministratorAccess'
)

# %% [markdown]
# Passa o serviço (s3).

# %%
s3 = session.client('s3')

# %% [markdown]
# Cria variáveis para nome do bucket, o nome do arquivo local, e o caminho do de armazenamento do bucket.

# %%
bucket = "analisedados"
arquivo = "ocorrencias_aeronauticas.csv"
caminho_s3 = "ocorrencias_aeronauticas.csv"

# %% [markdown]
# Faz o upload do arquivo.

# %%
s3.upload_file(arquivo, bucket, caminho_s3)
